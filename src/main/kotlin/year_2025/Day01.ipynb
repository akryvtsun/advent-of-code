// %%
val input = """
        L68
        L30
        R48
        L5
        R60
        L55
        L1
        L99
        R14
        L82
    """.trimIndent() .lines()

// %%
val input = File("../../../test/resources/year_2025/day_01_data.txt").readText().lines()

// %%
var position = 50
var count = 0
input.forEach { r ->
    val direction = if (r[0] == 'L') -1 else 1
    val times = r.drop(1).toInt()
    repeat(times) {
        position += direction
        if (position == -1) position = 99
        if (position == 100) position = 0
        if (position == 0) count++
    }
}
count
// Out:
// 6689
